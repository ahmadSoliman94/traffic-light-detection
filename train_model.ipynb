# %%
#!pip install -r requirements.txt
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement protoc>=3.19.0 (from versions: none)
# ERROR: No matching distribution found for protoc>=3.19.0

# %%
from  ultralytics import YOLO

# %%
pwd
# Out:
# '/notebooks/traffic-light-detection'

# %%
model = YOLO('yolov8l.pt')
model.train(data='/notebooks/traffic-light-detection/config.yaml',epochs=100,imgsz=640)
# Out:
# Ultralytics YOLOv8.0.117 🚀 Python-3.9.16 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A4000, 16117MiB)
# ...
